# %% [markdown]
# get_seq_from_web

# %%
import requests
from bs4 import BeautifulSoup


url = 'https://mouse.brain-map.org/experiment/show/75081210'
response = requests.get(url)
html = response.text

# %%
print(soup.find(text='Sequence:'))
# Out:
# None

# %%
print(soup.get_text())
# Out:
# Experiment Detail :: Allen Brain Atlas: Mouse Brain
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     This web browser is not configured to support JavaScript.
#     Many features may not operate correctly.
#     Please reconfigure your web browser to enable JavaScript, then refresh this page.
#
#
#
#
#
#
#
#
# ISH Data
#
#
# Reference Atlas
#
#
# AGEA
#
#
# Brain Explorer
#
#
#
#
#               Related Studies
#
#
# Sleep
#
# Mouse Strains
#
#
#
#
#
#
# Documentation
#
#
# Help

# %%
print(soup)

soup = BeautifulSoup(html, 'html.parser')
probe_sequence_element = soup.find(text='Sequence:').parent
probe_sequence = probe_sequence_element.next_sibling.strip()

print(probe_sequence)
# Out:
# <!DOCTYPE html>
#
# <head>
# <meta content="IE=10" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <meta content="atlas, gene, gene expression, brain, mouse" name="keywords"/>
# <meta content="375" name="version"/>
# <title>Experiment Detail :: Allen Brain Atlas: Mouse Brain</title>
# <link href="/assets/application-f12587859427410dea97f8259e4cc7a2.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/assets/common_layout-459e75a65bb7ebd0e584d269dcceef1c.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/assets/aiclient/manifests/ontology_autocomplete_manifest-32751654abe5d7683bb5f2a2317d41c5.css" media="screen" rel="stylesheet" type="text/css"/>
# <script>
#       if ( typeof window.JSON === 'undefined' ) {
#           document.write("<script src='/assets/aiclient/vendor/history/json2.js'><\/script>");
#       }
#       var _pSupressBrowserFlashWarning = true;
#   </script>
# <script src="/assets/manifests/aba_experiment_detail_manifest-3ee717d407bce827400747dfc23f4966.js" type="text/javascript"></script>
# <script>$j = jQuery.noConflict();</script>
# <link href="//www.brain-map.org/external_assets/stylesheets/portal.css" media="screen" rel="stylesheet" type="text/css"/>
# <script src="//www.brain-map.org/external_assets/javascripts/portal.js" type="text/javascript"></script>
# <script type="text/javascript">
# /***********************************************
# * AnyLink Drop Down Menu- © Dynamic Drive (www.dynamicdrive.com)
# * This notice MUST stay intact for legal use
# * Visit http://www.dynamicdrive.com/ for full source code
# ***********************************************/
# </script>
# <script type="text/javascript">
#   /*** each application needs to define these three variables ***/
#   var _pTabId = "pMouseBrain";                               // select "Mouse Brain" tab
#   var _pMoreProjectsId = "pMoreProjects";                    // specify ID of "More Projects" tab
#   var _pImagePath = "//www.brain-map.org/external_assets/images/";  // location of plugin image assets within the /public directory (must end with a '/")
# </script>
# <script type="text/javascript">
#   function initialize() {
#     /*** do your stuff, then initialize the portal plugin ***/
#     _pPortalOnLoad();
#   }
# </script>
# </head>
# <body onload="initialize()">
# <div class="siteContent">
# <style type="text/css">
#   p#js_cookie_check {
#     text-align:center;
#     font-size:medium;
#     color:#FF0000;
#     background-color:#FFFFFF;
#     border:thick double #4D6D86;
#     margin:10px;
#     padding:10px;
#   }
# </style>
# <noscript>
# <p id="js_cookie_check">
#     This web browser is not configured to support JavaScript.<br/>
#     Many features may not operate correctly.<br/>
#     Please reconfigure your web browser to enable JavaScript, then refresh this page.
#   </p>
# </noscript>
# <script type="text/javascript">
#   var tmpcookie = new Date();
#   chkcookie = (tmpcookie.getTime() + '');
#   document.cookie = "chkcookie=" + chkcookie + "; path=/";
#   if (document.cookie.indexOf(chkcookie,0) < 0) {
#     document.write("<p id='js_cookie_check'>");
#     document.write("This web browser is not configured to support Cookies.<br>");
#     document.write("Many features may not operate correctly.<br>");
#     document.write("Please reconfigure your web browser to enable Cookies, then refresh this page.");
#     document.write("</p>");
#   }
# </script>
# <script src="//www.brain-map.org/external_assets/javascripts/portalHeader.js" type="text/javascript"></script>
# <div id="pTabBar">
# <table id="app_menu_table">
# <tr>
# <td>
# <a class="pTabBarSelected" href="/search/index">ISH Data</a>
# </td>
# <td>
# <a class="subMenuOption" href="/static/atlas">Reference Atlas</a>
# </td>
# <td>
# <a class="subMenuOption" href="/agea">AGEA</a>
# </td>
# <td>
# <a class="subMenuOption be_option" href="/static/brainexplorer">Brain Explorer</a>
# </td>
# <td id="menu_cell">
# <ul class="app_menu_styles" id="nav">
# <li><a class="subMenuOption" href="#" id="top_menu">
#               Related Studies
#               <i class="icon-down-open"></i></a>
# <ul id="nav_menus">
# <li id="submenu_1"><a class="subMenuOption" href="/sleep">Sleep</a>
# </li>
# <li id="submenu_2"><a class="subMenuOption" href="/diversity">Mouse Strains</a>
# </li>
# </ul>
# </li>
# </ul>
# </td>
# <td>
# <a class="subMenuOption" href="/static/docs" id="doc_menu_link">Documentation</a>
# </td>
# <td>
# <a class="subMenuOption" href="/static/help" id="help_menu_link">Help</a>
# </td>
# </tr>
# </table>
# </div>
# <script>
# //  $j(document).ready( function() {
#     var mode = 'ish';
#     $j('#help_menu_link').bind('click', function(event) {
#         //var mode = '<--%= @mode %-->';
#         switch(mode) {
#             case 'ish':
#                window.open("http://help.brain-map.org/display/mousebrain/In+Situ+Hybridization+%28ISH%29+Data", '_help', 'status=0,toolbar=0,menubar=0,width=800,height=600,scrollbars=1,resizable=1');
#                break;
#             case 'sleep':
#                window.open("http://help.brain-map.org/display/mousebrain/Related+Studies#RelatedStudies-SleepStudy", '_help', 'status=0,toolbar=0,menubar=0,width=800,height=600,scrollbars=1,resizable=1');
#                break;
#             case 'diversity':
#                window.open("http://help.brain-map.org/display/mousebrain/Related+Studies#RelatedStudies-MouseStrainsStudy", '_help', 'status=0,toolbar=0,menubar=0,width=800,height=600,scrollbars=1,resizable=1');
#                break;
#             case 'atlas':
#                window.open("http://help.brain-map.org/display/atlasviewer/Allen+Mouse+Brain+Atlas", '_help', 'status=0,toolbar=0,menubar=0,width=800,height=600,scrollbars=1,resizable=1');
#                break;
#             case 'agea':
#                window.open("http://help.brain-map.org/display/mousebrain/Anatomic+Gene+Expression+Atlas+%28AGEA%29", '_help', 'status=0,toolbar=0,menubar=0,width=800,height=600,scrollbars=1,resizable=1');
#                break;
#             case 'brainexplorer':
#                window.open("http://help.brain-map.org/display/mousebrain/Brain+Explorer", '_help', 'status=0,toolbar=0,menubar=0,width=800,height=600,scrollbars=1,resizable=1');
#                break;
#             default:
#                window.open("http://help.brain-map.org/display/mousebrain", '_help', 'status=0,toolbar=0,menubar=0,width=800,height=600,scrollbars=1,resizable=1');
#         }
#
#         event.preventDefault();
#     });
#     $j('#doc_menu_link').bind('click', function(event) {
#         window.open("http://help.brain-map.org/display/mousebrain/Documentation", '_help', 'status=0,toolbar=0,menubar=0,width=800,height=600,scrollbars=1,resizable=1');
#         event.preventDefault();
#     });
#
#     if (mode == "sleep") {
#         jQuery('#top_menu').addClass('pTabBarSelected');
#     }
#     else if (mode == "diversity") {
#         jQuery('#top_menu').addClass('pTabBarSelected');
#     }
# //  } );
# </script>
# <style>
#     /* prevent wrap of top level menu item names when browser width reduced */
#     #app_menu_table td {
#         white-space: nowrap;
#         /*background-color: #CCC; */
#     }
#
#     /* special spacing on this element because of its relation to the drop-down menu */
#     .be_option {
#
#       padding-right:20px !important;
#     }
#
#     /* #nav is attached to the top level <ul> of the dropdown menu */
#     #nav {
#         margin: 0;
#         padding: 0;
#         list-style: none;
#         white-space: normal; /* prevent submenus from displaying horizontally in webkit */
#         z-index: 4000; /* added */
#     }
#
#         /* make the LI display inline */
#         /* it's position relative so that position absolute */
#         /* can be used in submenu */
#     #nav li {
#         float: left;
#         display: block;
#         position: relative;
#         z-index: 4000;
#         margin: 0 1px;
#         padding-right:20px;
#     }
#
#         /* this is the parent menu */
#     #nav li a {
#         display: block;
#         padding-left: 5px;
#         padding-right: 5px;
#         font-weight: 700;
#         height: 15px;
#         text-decoration: none;
#         text-align: center;
#         color: #FFFFFF;
#     }
#
#     #nav li a:hover {
#         color: #FFFFFF;
#     }
#
#     #nav a.selected {
#         color: #000000;
#     }
#
#         /* submenu, it's hidden by default */
#     #nav ul {
#         position: absolute;
#         left: 0;
#         display: none;
#         margin: 0px;
#         padding: 0;
#         list-style: none;
#         z-index: 4000; /* added */
#     }
#
#     #nav ul li {
#
#         white-space:nowrap;
#         float: left;
#         border-top: 1px solid #fff;
#     }
#
#         /* display block will make the link fill the whole area of <li> */
#     #nav ul a {
#         display: block;
#         height: 23px;
#         padding: 3px;
#         color: #646464;
#         background-color: #BBB; /* added */
#     }
#
#     #nav ul a:hover {
#         text-decoration: none;
#     }
#
#         /* ensure that the drop down parts of the menu are not obscured by other page elements; see ISH theme for example */
#     #nav_menus {
#         z-index: 4000;
#         min-width:158px;
#     }
#
#     #nav_menus li {
#         z-index: 4000;
#     }
#
#     #nav_menus li:first-child {
#
#       margin-top:10px;
#     }
#
#     /* ABA specific changes to accomodate June 2014 portal redesign */
#     #pTabBar {
#
#       padding:0px !important;
#       margin-bottom: 15px !important;
#     }
# </style>
# <table class="pageContent">
# <tr>
# <td>
# <div class="info_block" id="exp_detail"></div>
# <div id="filter_dialog_container"></div>
# <style>
#
# ._exp_detail_table ._graph_outer_container {
#    height:120px;
#    margin-bottom:2px;
#    margin-top:3px;
# }
#
# ._graph_legend {
#     margin-top:2px;
# }
#
#         #filter_dialog_container {
#
#             display:none;
#             font-size:0.8em !important;
#         }
#
#         #ui-dialog-title-filter_dialog_container .ui-widget {
#             font-size:0.8em !important;
#             color:#f00 !important;
#         }
#
# /* download_dialog controls */
#         #download_dialog_container {
#             display:none;
#             font-size:0.8em !important;
#         }
#
#         #ui-dialog-title-download_dialog_container .ui-widget {
#             font-size:0.8em !important;
#             color:#f00 !important;
#         }
#
# #exp_detail ._experiment_detail_failed {
#     background-color: #d88 !important;
# }
# </style>
# <script>
#
#     function trace(msg, level, obj) {
#
#         if(window.console)
#             window.console.log(msg);
#     }
#
#     function inspect(prefix, obj) {
#         var s = "";
#         for(key in obj) {
#             if((typeof obj[key]) == "function")
#                 s = s;
#             else if((typeof obj[key]) == "object" && obj[key] !== null & key != "element")
#                 s += "\n" + prefix + "key: " + key + inspect(prefix + "    ", obj[key]);
#             else
#                 s += "\n" + prefix + "key: " + key + ",   value: " + obj[key];
#         }
#         return(s);
#     }
#
#     var _experiment_id = '75081210';
#     var _application = null;
#     var _page = null;
#
#     function init() {
#         var app_options = {
#             theme:'ish',
#             urls:{
#                 data_service:'/api/v2/data/',
#                 analysis_service:'/mouse/data/',
#                 mapping_service:'/api/v2/',
#                 tabula_service:'/tabula/data/',
#
#                 differential_help : 'http://help.brain-map.org/display/mousebrain/In+Situ+Hybridization+%28ISH%29+Data#InSituHybridization%28ISH%29Data-DifferentialSearch',
#                 ivt : '/experiment/ivt',
#                 thumbnails:'/experiment/thumbnails',
#                 siv:'/experiment/siv',
#                 //siv:'http://developingmouse.brain-map.org/siv',
#                 brain_explorer:'aibe://mouse.brain-map.org/grid_data/v1/visualize/',
#                 related_data:'//www.brain-map.org/related/matches.jpg',
#                 threed_thumbnail:"/grid_data/mini_blended_thumbnail/",
#
#                 image_service:"/cgi-bin/imageservice?mime=2",
#                 tile_service:"/tiles/",
#                 info_service:"/tiles/",
#                 legend_service:"http://atlas.brain-map.org/atlas"
#             },
#             on_ready:load_page
#         };
#
#         _application = new application(app_options);
#
#     }
#
#     function load_page(app) {
#
#         var page_container = $j('#exp_detail');
#         _page = new app_page(page_container, 'experiment_detail', _application, {});
#
#         var opts = {
#             experiment_id:_experiment_id
#         };
#         new ish_experiment_detail_controller(page_container, _page, opts);
#         xml_link_aba_ish_experiment_detail('table.pageContent', 'xml', _experiment_id);
#     }
#
#     init();
#
# </script>
# </td>
# </tr>
# </table>
# </div>
# <div class="separator"></div>
# <div class="separator"></div>
# <div class="separator"></div>
# <div class="separator"></div>
# <script src="//www.brain-map.org/external_assets/javascripts/portalFooter.js" type="text/javascript"></script>
# </body>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2168\1636736750.py in <module>
#       2
#       3 soup = BeautifulSoup(html, 'html.parser')
# ----> 4 probe_sequence_element = soup.find(text='Sequence:').parent
#       5 probe_sequence = probe_sequence_element.next_sibling.strip()
#       6
#
# AttributeError: 'NoneType' object has no attribute 'parent'
